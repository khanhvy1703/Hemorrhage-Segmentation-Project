# %%
import pandas as pd
import numpy as np

df_flags = pd.read_csv("flagged.txt", header = None)
df_flags[0] = df_flags[0].apply(lambda x: x.split('.')[0])
df_flags
# Out:
#               0
# 0  ID_20440abc6
# 1  ID_1811d9bf2
# 2  ID_75a698178
# 3  ID_30010d605
# 4  ID_34b04fff9
# 5  ID_432bad415
# 6  ID_3cb85bfca
# 7  ID_4dad8b080
# 8  ID_6431af929

# %%
df_cat = pd.read_csv("hemorrhage-labels.csv")
df_cat
# Out:
#                Image  any  epidural  intraparenchymal  intraventricular  \
# 0       ID_000012eaf    0         0                 0                 0
# 1       ID_000039fa0    0         0                 0                 0
# 2       ID_00005679d    0         0                 0                 0
# 3       ID_00008ce3c    0         0                 0                 0
# 4       ID_0000950d7    0         0                 0                 0
# ...              ...  ...       ...               ...               ...
# 752798  ID_ffff82e46    0         0                 0                 0
# 752799  ID_ffff922b9    1         0                 0                 1
# 752800  ID_ffffb670a    1         0                 0                 0
# 752801  ID_ffffcbff8    0         0                 0                 0
# 752802  ID_fffff9393    0         0                 0                 0
#
#         subarachnoid  subdural
# 0                  0         0
# 1                  0         0
# ...

# %%
df_cat = df_cat[~df_cat.Image.isin(df_flags[0])]
df_cat.to_csv("hemorrhage-labels-removed-flags.csv")
df_cat
# Out:
#                Image  any  epidural  intraparenchymal  intraventricular  \
# 0       ID_000012eaf    0         0                 0                 0
# 1       ID_000039fa0    0         0                 0                 0
# 2       ID_00005679d    0         0                 0                 0
# 3       ID_00008ce3c    0         0                 0                 0
# 4       ID_0000950d7    0         0                 0                 0
# ...              ...  ...       ...               ...               ...
# 752798  ID_ffff82e46    0         0                 0                 0
# 752799  ID_ffff922b9    1         0                 0                 1
# 752800  ID_ffffb670a    1         0                 0                 0
# 752801  ID_ffffcbff8    0         0                 0                 0
# 752802  ID_fffff9393    0         0                 0                 0
#
#         subarachnoid  subdural
# 0                  0         0
# 1                  0         0
# ...

# %%
df_flags = pd.read_csv("flagged.txt", header = None)
df_flags
# Out:
#                   0
# 0  ID_20440abc6.jpg
# 1  ID_1811d9bf2.jpg
# 2  ID_75a698178.jpg
# 3  ID_30010d605.jpg
# 4  ID_34b04fff9.jpg
# 5  ID_432bad415.jpg
# 6  ID_3cb85bfca.jpg
# 7  ID_4dad8b080.jpg
# 8  ID_6431af929.jpg

# %%
df_epidural = pd.read_csv("Results_Epidural Hemorrhage Detection_2020-11-16_21.31.26.148.csv")
df_epidural
# Out:
#      Case ID            Origin                                         URL  \
# 0    1196514  ID_004c4b319.jpg  https://go.centaurlabs.com/problem/1196514
# 1    1196682  ID_0237b835f.jpg  https://go.centaurlabs.com/problem/1196682
# 2    1196477  ID_02e2d273d.jpg  https://go.centaurlabs.com/problem/1196477
# 3    1196612  ID_02f37ce84.jpg  https://go.centaurlabs.com/problem/1196612
# 4    1196612  ID_02f37ce84.jpg  https://go.centaurlabs.com/problem/1196612
# ..       ...               ...                                         ...
# 605  1196614  ID_879afbc77.jpg  https://go.centaurlabs.com/problem/1196614
# 606  1196600  ID_af76460ee.jpg  https://go.centaurlabs.com/problem/1196600
# 607  1196767  ID_d6d369eaa.jpg  https://go.centaurlabs.com/problem/1196767
# 608  1196539  ID_d9bfa60ed.jpg  https://go.centaurlabs.com/problem/1196539
# 609  1196955  ID_fa2874be0.jpg  https://go.centaurlabs.com/problem/1196955
#
# ...

# %%
df_epidural = df_epidural[~df_epidural.Origin.isin(df_flags[0])]
df_epidural.to_csv("EpiduralHemorrhageRemovedFlags.csv")
df_epidural
# Out:
#      Case ID            Origin                                         URL  \
# 0    1196514  ID_004c4b319.jpg  https://go.centaurlabs.com/problem/1196514
# 1    1196682  ID_0237b835f.jpg  https://go.centaurlabs.com/problem/1196682
# 2    1196477  ID_02e2d273d.jpg  https://go.centaurlabs.com/problem/1196477
# 3    1196612  ID_02f37ce84.jpg  https://go.centaurlabs.com/problem/1196612
# 4    1196612  ID_02f37ce84.jpg  https://go.centaurlabs.com/problem/1196612
# ..       ...               ...                                         ...
# 605  1196614  ID_879afbc77.jpg  https://go.centaurlabs.com/problem/1196614
# 606  1196600  ID_af76460ee.jpg  https://go.centaurlabs.com/problem/1196600
# 607  1196767  ID_d6d369eaa.jpg  https://go.centaurlabs.com/problem/1196767
# 608  1196539  ID_d9bfa60ed.jpg  https://go.centaurlabs.com/problem/1196539
# 609  1196955  ID_fa2874be0.jpg  https://go.centaurlabs.com/problem/1196955
#
# ...

# %%
df_intraparenchymal = pd.read_csv("Results_Intraparenchymal Hemorrhage Detection_2020-11-16_21.39.31.268.csv")
df_intraparenchymal
# Out:
#       Case ID            Origin                                         URL  \
# 0     1675660  ID_0002081b6.jpg  https://go.centaurlabs.com/problem/1675660
# 1     1675942  ID_0048e60a4.jpg  https://go.centaurlabs.com/problem/1675942
# 2     1197689  ID_0057d2736.jpg  https://go.centaurlabs.com/problem/1197689
# 3     1197754  ID_007cac3b7.jpg  https://go.centaurlabs.com/problem/1197754
# 4     1675775  ID_00b46c6bc.jpg  https://go.centaurlabs.com/problem/1675775
# ...       ...               ...                                         ...
# 1284  1676054  ID_30010d605.jpg  https://go.centaurlabs.com/problem/1676054
# 1285  1675679  ID_4d5dac21b.jpg  https://go.centaurlabs.com/problem/1675679
# 1286  1197797  ID_664eb0683.jpg  https://go.centaurlabs.com/problem/1197797
# 1287  1197716  ID_e45ff2e50.jpg  https://go.centaurlabs.com/problem/1197716
# 1288  1197511  ID_f797f771e.jpg  https://go.centaurlabs.com/problem/1197511
#
# ...

# %%
df_intraparenchymal = df_intraparenchymal[~df_intraparenchymal.Origin.isin(df_flags[0])]
df_intraparenchymal.to_csv("IntraparenchymalHemorrhageRemovedFlags.csv")
df_intraparenchymal
# Out:
#       Case ID            Origin                                         URL  \
# 0     1675660  ID_0002081b6.jpg  https://go.centaurlabs.com/problem/1675660
# 1     1675942  ID_0048e60a4.jpg  https://go.centaurlabs.com/problem/1675942
# 2     1197689  ID_0057d2736.jpg  https://go.centaurlabs.com/problem/1197689
# 3     1197754  ID_007cac3b7.jpg  https://go.centaurlabs.com/problem/1197754
# 4     1675775  ID_00b46c6bc.jpg  https://go.centaurlabs.com/problem/1675775
# ...       ...               ...                                         ...
# 1283  1676103  ID_2efe8b804.jpg  https://go.centaurlabs.com/problem/1676103
# 1285  1675679  ID_4d5dac21b.jpg  https://go.centaurlabs.com/problem/1675679
# 1286  1197797  ID_664eb0683.jpg  https://go.centaurlabs.com/problem/1197797
# 1287  1197716  ID_e45ff2e50.jpg  https://go.centaurlabs.com/problem/1197716
# 1288  1197511  ID_f797f771e.jpg  https://go.centaurlabs.com/problem/1197511
#
# ...

# %%
df_subarachnoid = pd.read_csv("Results_Subarachnoid Hemorrhage Detection_2020-11-16_21.36.18.668.csv")
df_subarachnoid
# Out:
#       Case ID            Origin                                         URL  \
# 0     1197112  ID_001b1b944.jpg  https://go.centaurlabs.com/problem/1197112
# 1     1197112  ID_001b1b944.jpg  https://go.centaurlabs.com/problem/1197112
# 2     1197112  ID_001b1b944.jpg  https://go.centaurlabs.com/problem/1197112
# 3     1197367  ID_005f428d2.jpg  https://go.centaurlabs.com/problem/1197367
# 4     1197367  ID_005f428d2.jpg  https://go.centaurlabs.com/problem/1197367
# ...       ...               ...                                         ...
# 1026  1197026  ID_ffb8b3408.jpg  https://go.centaurlabs.com/problem/1197026
# 1027  1197288  ID_ffc54be74.jpg  https://go.centaurlabs.com/problem/1197288
# 1028  1197288  ID_ffc54be74.jpg  https://go.centaurlabs.com/problem/1197288
# 1029  1197157  ID_0cefcaa16.jpg  https://go.centaurlabs.com/problem/1197157
# 1030  1197175  ID_ac8229f7a.jpg  https://go.centaurlabs.com/problem/1197175
#
# ...

# %%
df_subarachnoid = df_subarachnoid[~df_subarachnoid.Origin.isin(df_flags[0])]
df_subarachnoid.to_csv("SubarachnoidHemorrhageRemovedFlags.csv")
df_subarachnoid
# Out:
#       Case ID            Origin                                         URL  \
# 0     1197112  ID_001b1b944.jpg  https://go.centaurlabs.com/problem/1197112
# 1     1197112  ID_001b1b944.jpg  https://go.centaurlabs.com/problem/1197112
# 2     1197112  ID_001b1b944.jpg  https://go.centaurlabs.com/problem/1197112
# 3     1197367  ID_005f428d2.jpg  https://go.centaurlabs.com/problem/1197367
# 4     1197367  ID_005f428d2.jpg  https://go.centaurlabs.com/problem/1197367
# ...       ...               ...                                         ...
# 1026  1197026  ID_ffb8b3408.jpg  https://go.centaurlabs.com/problem/1197026
# 1027  1197288  ID_ffc54be74.jpg  https://go.centaurlabs.com/problem/1197288
# 1028  1197288  ID_ffc54be74.jpg  https://go.centaurlabs.com/problem/1197288
# 1029  1197157  ID_0cefcaa16.jpg  https://go.centaurlabs.com/problem/1197157
# 1030  1197175  ID_ac8229f7a.jpg  https://go.centaurlabs.com/problem/1197175
#
# ...

# %%
df_subdural = pd.read_csv("Results_Subdural Hemorrhage Detection_2020-11-16_21.37.19.745.csv")
df_subdural
# Out:
#      Case ID            Origin                                         URL  \
# 0    1198320  ID_0061cb462.jpg  https://go.centaurlabs.com/problem/1198320
# 1    1198320  ID_0061cb462.jpg  https://go.centaurlabs.com/problem/1198320
# 2    1198004  ID_0086b5e67.jpg  https://go.centaurlabs.com/problem/1198004
# 3    1198004  ID_0086b5e67.jpg  https://go.centaurlabs.com/problem/1198004
# 4    1198353  ID_00eb6f7cc.jpg  https://go.centaurlabs.com/problem/1198353
# ..       ...               ...                                         ...
# 747  1197978  ID_c0bfa10d4.jpg  https://go.centaurlabs.com/problem/1197978
# 748  1198037  ID_04f4f9961.jpg  https://go.centaurlabs.com/problem/1198037
# 749  1198103  ID_39cacf303.jpg  https://go.centaurlabs.com/problem/1198103
# 750  1198171  ID_522d2c708.jpg  https://go.centaurlabs.com/problem/1198171
# 751  1198216  ID_526a44302.jpg  https://go.centaurlabs.com/problem/1198216
#
# ...

# %%
df_subdural = df_subdural[~df_subdural.Origin.isin(df_flags[0])]
df_subdural.to_csv("SubduralHemorrhageRemovedFlags.csv")
df_subdural
# Out:
#      Case ID            Origin                                         URL  \
# 0    1198320  ID_0061cb462.jpg  https://go.centaurlabs.com/problem/1198320
# 1    1198320  ID_0061cb462.jpg  https://go.centaurlabs.com/problem/1198320
# 2    1198004  ID_0086b5e67.jpg  https://go.centaurlabs.com/problem/1198004
# 3    1198004  ID_0086b5e67.jpg  https://go.centaurlabs.com/problem/1198004
# 4    1198353  ID_00eb6f7cc.jpg  https://go.centaurlabs.com/problem/1198353
# ..       ...               ...                                         ...
# 747  1197978  ID_c0bfa10d4.jpg  https://go.centaurlabs.com/problem/1197978
# 748  1198037  ID_04f4f9961.jpg  https://go.centaurlabs.com/problem/1198037
# 749  1198103  ID_39cacf303.jpg  https://go.centaurlabs.com/problem/1198103
# 750  1198171  ID_522d2c708.jpg  https://go.centaurlabs.com/problem/1198171
# 751  1198216  ID_526a44302.jpg  https://go.centaurlabs.com/problem/1198216
#
# ...

# %%
df_multiple = pd.read_csv("Results_Multiple Hemorrhage Detection_2020-11-16_21.36.24.018.csv")
df_multiple
# Out:
#       Case ID            Origin                                         URL  \
# 0     1198534  ID_01af922c3.jpg  https://go.centaurlabs.com/problem/1198534
# 1     1198534  ID_01af922c3.jpg  https://go.centaurlabs.com/problem/1198534
# 2     1198534  ID_01af922c3.jpg  https://go.centaurlabs.com/problem/1198534
# 3     1198791  ID_01c457a64.jpg  https://go.centaurlabs.com/problem/1198791
# 4     1198791  ID_01c457a64.jpg  https://go.centaurlabs.com/problem/1198791
# ...       ...               ...                                         ...
# 1049  1198749  ID_feef88292.jpg  https://go.centaurlabs.com/problem/1198749
# 1050  1198944  ID_ff88e4f59.jpg  https://go.centaurlabs.com/problem/1198944
# 1051  1198747  ID_ffd581895.jpg  https://go.centaurlabs.com/problem/1198747
# 1052  1198747  ID_ffd581895.jpg  https://go.centaurlabs.com/problem/1198747
# 1053  1198747  ID_ffd581895.jpg  https://go.centaurlabs.com/problem/1198747
#
# ...

# %%
df_multiple = df_multiple[~df_multiple.Origin.isin(df_flags[0])]
df_multiple.to_csv("MultipleHemorrhageRemovedFlags.csv")
df_multiple
# Out:
#       Case ID            Origin                                         URL  \
# 0     1198534  ID_01af922c3.jpg  https://go.centaurlabs.com/problem/1198534
# 1     1198534  ID_01af922c3.jpg  https://go.centaurlabs.com/problem/1198534
# 2     1198534  ID_01af922c3.jpg  https://go.centaurlabs.com/problem/1198534
# 3     1198791  ID_01c457a64.jpg  https://go.centaurlabs.com/problem/1198791
# 4     1198791  ID_01c457a64.jpg  https://go.centaurlabs.com/problem/1198791
# ...       ...               ...                                         ...
# 1049  1198749  ID_feef88292.jpg  https://go.centaurlabs.com/problem/1198749
# 1050  1198944  ID_ff88e4f59.jpg  https://go.centaurlabs.com/problem/1198944
# 1051  1198747  ID_ffd581895.jpg  https://go.centaurlabs.com/problem/1198747
# 1052  1198747  ID_ffd581895.jpg  https://go.centaurlabs.com/problem/1198747
# 1053  1198747  ID_ffd581895.jpg  https://go.centaurlabs.com/problem/1198747
#
# ...

# %%
df_intraventricular  = pd.read_csv("Results_Brain Hemorrhage Tracing_2020-09-28_15.21.52.597.csv")
df_intraventricular
# Out:
#       Case ID            Origin                                        URL  \
# 0      613914  ID_00042829c.jpg  https://go.centaurlabs.com/problem/613914
# 1      610884  ID_0009db386.jpg  https://go.centaurlabs.com/problem/610884
# 2      613269  ID_001753ad0.jpg  https://go.centaurlabs.com/problem/613269
# 3      613269  ID_001753ad0.jpg  https://go.centaurlabs.com/problem/613269
# 4      613823  ID_0018428e1.jpg  https://go.centaurlabs.com/problem/613823
# ...       ...               ...                                        ...
# 2394   618346  ID_ff91e9141.jpg  https://go.centaurlabs.com/problem/618346
# 2395   612431  ID_165e38265.jpg  https://go.centaurlabs.com/problem/612431
# 2396   608949  ID_1f607014a.jpg  https://go.centaurlabs.com/problem/608949
# 2397   609302  ID_3b6f7b33d.jpg  https://go.centaurlabs.com/problem/609302
# 2398   613534  ID_5793e77de.jpg  https://go.centaurlabs.com/problem/613534
#
# ...

# %%
df_intraventricular = df_intraventricular[~df_intraventricular.Origin.isin(df_flags[0])]
df_intraventricular.to_csv("IntraventricularHemorrhageRemovedFlags.csv")
df_intraventricular
# Out:
#       Case ID            Origin                                        URL  \
# 0      613914  ID_00042829c.jpg  https://go.centaurlabs.com/problem/613914
# 1      610884  ID_0009db386.jpg  https://go.centaurlabs.com/problem/610884
# 2      613269  ID_001753ad0.jpg  https://go.centaurlabs.com/problem/613269
# 3      613269  ID_001753ad0.jpg  https://go.centaurlabs.com/problem/613269
# 4      613823  ID_0018428e1.jpg  https://go.centaurlabs.com/problem/613823
# ...       ...               ...                                        ...
# 2394   618346  ID_ff91e9141.jpg  https://go.centaurlabs.com/problem/618346
# 2395   612431  ID_165e38265.jpg  https://go.centaurlabs.com/problem/612431
# 2396   608949  ID_1f607014a.jpg  https://go.centaurlabs.com/problem/608949
# 2397   609302  ID_3b6f7b33d.jpg  https://go.centaurlabs.com/problem/609302
# 2398   613534  ID_5793e77de.jpg  https://go.centaurlabs.com/problem/613534
#
# ...
